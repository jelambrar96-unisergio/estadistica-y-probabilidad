# %% [markdown]
# # Parcial 1 - Estadística y probabilidad
#
# ## Universidad Sergio Arboleda
#
# Nombre: **ESCRIBA SU NOMBRE AQUÍ**

# %% [markdown]
# Para el ejercicio de hoy se ha seleccionado una base de datos de precios de vehículos. El objetivo es realizar un análisis descriptivo de la variable de precios de vehículos.

# %% [markdown]
# El primer paso consiste en descargar el conjunto de datos. Al ejecutarse la siguiente celda se descargará un archivo csv que contiene los precios de los vehículos.

# %%
# !wget -O carprice.csv https://raw.githubusercontent.com/Azure/carprice/refs/heads/master/dataset/carprice.csv

# %% [markdown]
# Se utilizarán bibliotecas de python relacionadas con análisis y visualización de datos. Entre ellas **pandas**, **matplotlib** y **seaborn**.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("carprice.csv")

# %% [markdown]
# Para este ejercicio se ha realizado un filtrado de la columna **price**,alguno de sus valores son iguales a `?` lo que impide realizar la conversión a número flotante.

# %%
df = df[df["price"] != "?"]
df["price"] = df["price"].astype(float)

# %%
df.info()

# %%
df.head(5)

# %% [markdown]
# ## Pregunta 1. (10 puntos)
#
# Halle la media de los precios de los vechículos.
#
# 1. 12763.12
# 2. 13248.02
# 3. 14234.67
# 4. 15172.39

# %% [markdown]
# ## Pregunta 2. (10 puntos)
#
# Halle la desvicación estándar del precio de los vehículos.
#
# 1. 6056.33
# 2. 7056.33
# 3. 8056.33
# 4. 9056.33

# %% [markdown]
# ## Pregunta 3 (10 puntos)
#
# Halle la mediana y los percentiles p25 y p75.
#
# 1. Mediana: 10245, p25: 7756 y p75: 16509.
# 2. Mediana: 10245, p25: 8102 y p75: 15873.
# 3. Mediana: 10245, p25: 7124 y p75: 17340.
# 4. Mediana: 10245, p25: 6985 y p75: 16201.

# %% [markdown]
# ## Pregunta 4 (20 puntos)
#
# Según los valores de media, mediana y percentiles p25 y p75. ¿Qué se puede inferir de la distribución de la variable?

# %% [markdown]
# ## Pregunta 5 (20 puntos)
#
# 1. Construye un histograma de los precios de los vehículos.
# 2. Escribe qué características tiene el histograma.

# %% [markdown]
# ## Pregunta 6 (20 puntos)
#
# 1. Construye un diagrama de cajas y bigotes (boxplot) de la variable precio.
# 2. ¿Qué se puede afirma acerca de los valores atípicos en la distribución?

# %% [markdown]
# ## Pregunta 7 (10 puntos)
#
# 1. Construye un diagrama de cajas y bigotes (boxplot) de los precios de los vehículos vs su marca. Saca las respectivas conclusiones.

# %% [markdown]
# ## Pregunta 8 (Bonus - 20 puntos)
#
# Utiliza la función de numpy `np.log1p` para hacer una transformación de los precios de los vehiculos. Luego, grafica nuevamente el histograma de precios y el diagrama de cajas de bigotes. Comente el efecto de realizar esta transformación.
