# %% [markdown]
# # Distribución Multinomial
#
# La distribución multinomial generaliza la binomial a múltiples categorías. Modela los conteos de resultados en $n$ ensayos de categorías mutuamente excluyentes.
#
# Si las probabilidades son $p_1, \dots, p_m$ y los conteos son $k_1, \dots, k_m$ con $\sum k_i = n$:
#
# $$
# P(X_1 = k_1, \dots, X_m = k_m) = \frac{n!}{k_1! \cdots k_m!} p_1^{k_1} \cdots p_m^{k_m}
# $$

# %%
from math import factorial


def multinomial_pmf(n, ps, ks):
    pass

n = 5
ps = [1/6] * 6
ks = [2, 2, 1, 0, 0, 0]
print('P([2,2,1,0,0,0]) en 5 lanzamientos:', multinomial_pmf(n, ps, ks))

# %% [markdown]
# ## Ejemplo de cálculo con SciPy

# %%
from scipy.stats import multinomial

rv = multinomial(5, [1/6] * 6)
print('P([2,2,1,0,0,0]) con scipy:', rv.pmf([2, 2, 1, 0, 0, 0]))

# %% [markdown]
# ### Ejercicio propuesto
#
# En 5 lanzamientos de un dado justo, calcula la probabilidad de obtener exactamente 2 unos, 2 doses y 1 tres.
