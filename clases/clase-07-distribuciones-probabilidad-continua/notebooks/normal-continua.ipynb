# %% [markdown]
# # Distribución Normal
#
# La distribución normal, también conocida como distribución de Gauss o "campana de Gauss", es la distribución más importante en estadística. Muchos fenómenos naturales y sociales siguen esta distribución (estatura, errores de medición, puntajes de exámenes).
#
# ### Definición matemática
#
# Una variable aleatoria continua $X$ sigue una distribución normal con media $\mu$ y varianza $\sigma^2$ si su PDF es:
#
# $$f(x) = \frac{1}{\sigma \sqrt{2\pi}} e^{-\frac{1}{2} \left( \frac{x-\mu}{\sigma} \right)^2}, \quad -\infty < x < \infty$$
#
# ### Características
#
# - **Media**: $E[X] = \mu$
# - **Varianza**: $Var[X] = \sigma^2$
# - **Simetría**: Es perfectamente simétrica respecto a $\mu$. La media, mediana y moda coinciden.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

## Ejercicio: Graficar múltiples distribuciones con diferentes parámetros

x = np.linspace(-10, 10, 1000)
parametros = [(0, 1), (0, 2), (2, 1)]
colores = ['blue', 'green', 'red']

plt.figure(figsize=(10, 6))

for (mu, sigma), color in zip(parametros, colores):
    pdf = norm.pdf(x, loc=mu, scale=sigma)
    plt.plot(x, pdf, label=f'Normal($\mu={mu}, \sigma={sigma}$)', color=color, lw=2)
    plt.fill_between(x, pdf, color=color, alpha=0.1)

plt.title('Comparación de Distribuciones Normales')
plt.xlabel('x')
plt.ylabel('Densidad de Probabilidad')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# **6.5** Dada una distribución normal estándar, calcule el área bajo la curva que está
#
# 1. a la izquierda de z = –1.39;
# 2. a la derecha de z = 1.96;
# 3. entre z = –2.16 y z = – 0.65;
# 4. a la izquierda de z = 1.43;
# 5. a la derecha de z = – 0.89;
# 6. entre z = – 0.48 y z = 1.74.

# %% [markdown]
# **6.6** Calcule el valor de z si el área bajo una curva normal estándar
#
# 1. a la derecha de z es 0.3622;
# 2. a la izquierda de z es 0.1131;
# 3. entre 0 y z, con z > 0, es 0.4838;
# 4. entre –z y z, con z > 0, es 0.9500.

# %% [markdown]
# **6.7** Dada una distribución normal estándar, calcule el valor de k tal que
#
# 1. P (Z > k) = 0.2946;
# 2. P (Z < k) = 0.0427;
# 3. P (−0.93 < Z < k) = 0.7235.

# %% [markdown]
# **6.8** Dada una distribución normal con $\mu = 30$ y $\sigma = 6$, calcule
#
# 1. el área de la curva normal a la derecha de x = 17;
# 2. el área de la curva normal a la izquierda de x = 22;
# 3. el área de la curva normal entre x = 32 y x = 41;
# 4. el valor de x que tiene 80% del área de la curva normal a la izquierda;
# 5. los dos valores de x que contienen 75% central del
# área de la curva normal.

# %% [markdown]
# **6.9** Dada la variable X normalmente distribuida con una media de 18 y una desviación estándar de 2.5, calcule
#
# 1. P(X < 15);
# 2. el valor de k tal que P(X < k) = 0.2236;
# 3. el valor de k tal que P(X > k) = 0.1814;
# 4. P(17 < X < 21).

# %% [markdown]
# **6.24** Se lanza una moneda 400 veces. Utilice la aproximación a la curva normal para calcular la probabilidad de obtener
#
# 1. entre 185 y 210 caras;
# 2. exactamente 205 caras;
# 3. menos de 176 o más de 227 caras.
