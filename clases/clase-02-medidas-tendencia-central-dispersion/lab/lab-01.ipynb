# %% [markdown]
# # Taller: visualización de datos

# %%
# !wget -O house_prices.csv https://raw.githubusercontent.com/jelambrar96-datatalks/house-price-predictor/main/dataset/train.csv

# %% [markdown]
# ## 1. Lectura del archivo
#
# Para la lectura del archivo se utilizará el paquete pandas
#
# ```python
# df = pd.read_csv("nombre_archivo_csv")
# ```

# %% [markdown]
# ## 2.
